# %%
import cv2 as cv2
import matplotlib.pyplot as plt

# %%
img1 = cv2.imread('images/almanac.jpg')
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)

img2 = cv2.imread('images/desk.jpg')
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(img1, cmap='gray', vmin=0, vmax=255)

# %%
plt.imshow(img2, cmap='gray', vmin=0, vmax=255)

# %% [markdown]
# initiate SIFT

# %%
sift = cv2.SIFT_create()

# %%
keypoints1, descriptors1 = sift.detectAndCompute(img1, None)
keypoints2, descriptors2 = sift.detectAndCompute(img2, None)

# %% [markdown]
# brute-force matcher

# %%
bf = cv2.BFMatcher(cv2.NORM_L2)
matches = bf.match(descriptors1, descriptors2)

# %%
len(keypoints1)
# Out:
# 1777

# %%
len(keypoints2)
# Out:
# 12125

# %%
matches = sorted(matches, key = lambda x:x.distance)

# %%
matches[:10]
# Out:
# [< cv2.DMatch 0x132a7b9f0>,
#  < cv2.DMatch 0x132a771b0>,
#  < cv2.DMatch 0x132a7e4d0>,
#  < cv2.DMatch 0x132a7c0b0>,
#  < cv2.DMatch 0x132a7eeb0>,
#  < cv2.DMatch 0x132a74870>,
#  < cv2.DMatch 0x132a7b630>,
#  < cv2.DMatch 0x132a74a10>,
#  < cv2.DMatch 0x132a74810>,
#  < cv2.DMatch 0x132a78e50>]

# %%
image_matched = cv2.drawMatches(img1, keypoints1, img2, keypoints2, matches[:10], None, flags=cv2.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS, matchesThickness=3)

# %%
plt.imshow(image_matched)
