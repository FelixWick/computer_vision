# %%
! pip install opencv-python
! pip install matplotlib
# Out:
# Requirement already satisfied: opencv-python in c:\users\70p6229\computer_vision\examples\.venv\lib\site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\70p6229\computer_vision\examples\.venv\lib\site-packages (from opencv-python) (2.2.4)
# Requirement already satisfied: matplotlib in c:\users\70p6229\computer_vision\examples\.venv\lib\site-packages (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\70p6229\computer_vision\examples\.venv\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\70p6229\computer_vision\examples\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\70p6229\computer_vision\examples\.venv\lib\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\70p6229\computer_vision\examples\.venv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\70p6229\computer_vision\examples\.venv\lib\site-packages (from matplotlib) (2.2.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\70p6229\computer_vision\examples\.venv\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\70p6229\computer_vision\examples\.venv\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\70p6229\computer_vision\examples\.venv\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\70p6229\computer_vision\examples\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\70p6229\computer_vision\examples\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread('FCK.png')

# %% [markdown]
# plotting with OpenCV directly

# %%
def opencv_plotting(window_name, image):
    window_name = 'FCK'

    cv2.imshow(window_name, image)

    # waits for user to press any key
    # (this is necessary to avoid Python kernel form crashing)
    cv2.waitKey(0)

    # closing all open windows
    cv2.destroyAllWindows()

# %%
opencv_plotting('FCK', image)

# %% [markdown]
# plotting with Matplotlib

# %%
# call imshow() using plt object
plt.imshow(image)

# display that image
plt.show()

# %% [markdown]
# Hm. We will fix this later ...
