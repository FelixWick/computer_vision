# %%
! pip install pywavelets
# Out:
# Requirement already satisfied: pywavelets in c:\users\70p6229\computer_vision\examples\.venv\lib\site-packages (1.8.0)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\70p6229\computer_vision\examples\.venv\lib\site-packages (from pywavelets) (2.2.4)

# %%
import matplotlib.pyplot as plt
import pywt

# %%
# load image
original = pywt.data.camera()

# discrete wavelet transform to image
coeffs2 = pywt.dwt2(original, 'haar')

# %%
titles = ['Approximation', ' Horizontal detail', 'Vertical detail', 'Diagonal detail']
LL, (LH, HL, HH) = coeffs2

# %%
fig = plt.figure(figsize=(12, 3))

for i, a in enumerate([LL, LH, HL, HH]):
    ax = fig.add_subplot(1, 4, i + 1)
    ax.imshow(a, interpolation="nearest", cmap='gray')
    ax.set_title(titles[i], fontsize=10)
    ax.set_xticks([])
    ax.set_yticks([])

fig.tight_layout()
plt.show()
