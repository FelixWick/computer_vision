# %%
! pip install pywavelets
# Out:
# Collecting pywavelets
#   Downloading pywavelets-1.9.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (7.6 kB)
# Requirement already satisfied: numpy<3,>=1.25 in /Users/wick/computer_vision/examples/.venv/lib/python3.13/site-packages (from pywavelets) (2.2.6)
# Downloading pywavelets-1.9.0-cp313-cp313-macosx_11_0_arm64.whl (4.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 45.4 MB/s  0:00:00
# Installing collected packages: pywavelets
# Successfully installed pywavelets-1.9.0

# %%
import matplotlib.pyplot as plt
import pywt

# %%
# load image
original = pywt.data.camera()

# discrete wavelet transform to image
coeffs2 = pywt.dwt2(original, 'haar')

# %%
titles = ['Approximation', ' Horizontal detail', 'Vertical detail', 'Diagonal detail']
LL, (LH, HL, HH) = coeffs2

# %%
fig = plt.figure(figsize=(12, 3))

for i, a in enumerate([LL, LH, HL, HH]):
    ax = fig.add_subplot(1, 4, i + 1)
    ax.imshow(a, interpolation="nearest", cmap='gray')
    ax.set_title(titles[i], fontsize=10)
    ax.set_xticks([])
    ax.set_yticks([])

fig.tight_layout()
plt.show()
